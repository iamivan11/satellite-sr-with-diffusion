# %% [markdown]
# ## 1. Install dependencies

# %%
# !pip install -r /content/diwa_colab/requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 118.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 99.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 54.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 42.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 102.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.9/981.9 kB 65.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 5.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## 2. Connect to Wandb for monitoring the training

# %%
# You will be prompted for your API key
# !wandb login
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: ivansorokin (ivansorokin_msc_project) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %% [markdown]
# ## 3. Evaluation Settings
# - Stage: 3
# - Experiment: 2
# - Train Data: SEN2VENUS
# - Resolution: **2x**
# - Train LR Type: **Real**
# - Test Data: SEN2VENUS
# - Test LR Type: **Real**
# - Model:
#   - Architecuture: Wave
#   - Epochs: 60
#   - Noise Schedule: Linear
#   - Loss: L1
#   - Optimizer: AdamW
#   - Batch Size: 32
#   - Learning Rate: 5e-5
#   - Weight Decay: 1e-4
#   - Gradient Clipping: 1

# %%
# !python /rds/homes/i/ixs490/msc-project/code/main.py -c /rds/homes/i/ixs490/msc-project/code/config/sen2venus/wave/val_config_2x.json -p val -enable_wandb
# Out:
# export CUDA_VISIBLE_DEVICES=0
# wandb: Currently logged in as: ivansorokin (ivansorokin_msc_project) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /rds/projects/r/rajpookm-deep-learning/ixs490/experiments/s2v_2x_wave_attn2/wandb/run-20250830_132241-y23j8sag
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run s2v_2x_wave_attn2
# wandb: ⭐️ View project at https://wandb.ai/ivansorokin_msc_project/colab_eval_2
# wandb: 🚀 View run at https://wandb.ai/ivansorokin_msc_project/colab_eval_2/runs/y23j8sag
# ...
# sampling loop time step:  61%|█████████▊      | 306/500 [00:03<00:02, 85.94it/s]
