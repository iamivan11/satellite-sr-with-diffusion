# %% [markdown]
# ## 1. Install dependencies

# %%
# !pip install -r /rds/homes/i/ixs490/msc-project/code_colab/requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached torch-2.7.1-cp310-cp310-manylinux_2_28_x86_64.whl (821.2 MB)
# ...
#   Using cached torchvision-0.22.1-cp310-cp310-manylinux_2_28_x86_64.whl (7.5 MB)
# ...
#   Using cached torchmetrics-1.8.0-py3-none-any.whl (981 kB)
# ...
#   Using cached lpips-0.1.4-py3-none-any.whl (53 kB)
# ...
#   Using cached pytorch_wavelets-1.3.0-py3-none-any.whl (54 kB)
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## 2. Connect to Wandb for monitoring the training

# %%
# You will be prompted for your API key
# !wandb login
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /rds/homes/i/ixs490/.netrc
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin

# %% [markdown]
# ## 3. Training Settings:
# - Stage: 3
# - Experiment: 1
# - Train Data: SEN2VENUS
# - Resolution: **2x**
# - Train LR Type: **Real**
# - Model:
#   - Architecuture: Wave
#   - Epochs: 60
#   - Noise Schedule: Linear
#   - Loss: L1
#   - Optimizer: AdamW
#   - Batch Size: 32
#   - Learning Rate: 5e-5
#   - Weight Decay: 1e-4
#   - Gradient Clipping: 1

# %%
import torch
torch.cuda.get_device_name()
# Out:
# 'NVIDIA A100-SXM4-40GB'

# %%
# !python /rds/homes/i/ixs490/msc-project/code/main.py -c /rds/homes/i/ixs490/msc-project/code/config/sen2venus/wave/train_new_config_2x.json -p train -enable_wandb
# Out:
# export CUDA_VISIBLE_DEVICES=0
# wandb: Currently logged in as: ivansorokin (ivansorokin_msc_project) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /rds/projects/r/rajpookm-deep-learning/ixs490/experiments/wandb/run-20250829_105819-xf9wg4bv
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run s2v_2x_s_wave_attn2
# wandb: ⭐️ View project at https://wandb.ai/ivansorokin_msc_project/colab_train_6
# wandb: 🚀 View run at https://wandb.ai/ivansorokin_msc_project/colab_train_6/runs/xf9wg4bv
# 25-08-29 10:58:24.719 -   name: s2v_2x_s_wave_attn2
#   gpu_ids: [0]
#   path:[
#     log: /rds/projects/r/rajpookm-deep-learning/ixs490/experiments/experiments/s2v_2x_s_wave_attn2/logs
#     results: /rds/projects/r/rajpookm-deep-learning/ixs490/experiments/experiments/s2v_2x_s_wave_attn2/results
# ...
